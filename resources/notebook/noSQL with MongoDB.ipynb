# %%
import requests
from pymongo import MongoClient

# %%
uri = "mongodb://strongadmin:12341234@ds123500.mlab.com:23500/collections"

# %%
client = MongoClient(uri)

# %%
client.collections.collection_names()
# Out:
# ['users', 'system.indexes']

# %%
one_user = {
    "name":"김패캠",
    "email":"fckim@fastcampus.co.kr",
    "phone":1026547861,
    "age":28,
    "gender":"M",
    "locale":"서울 강남구",
}

# %%
# db와 users collection 선택하기
db = client.collections
users = db.users

# %%
# 또는
db = client["collections"]
users = db["users"]

# %%
users.insert_one(one_user)

# %%
users.find_one()
# Out:
# {'_id': ObjectId('5afc14aadabf947affd94358'),
#  'name': '김패캠',
#  'email': 'fckim@fastcampus.co.kr',
#  'phone': 1026547861,
#  'age': 28,
#  'gender': 'M',
#  'locale': '서울 강남구'}

# %%
many_user = [
    {
        "name":"psy",
        "email":"jspark@fastcampus.co.kr",
        "phone":1012342850,
        "age":40,
        "gender":"M",
        "locale":"서울 강남구",
    },
    {
        "name":"Gdragon",
        "email":"jypark@fastcampus.co.kr",
        "phone":1082651029,
        "age":29,
        "gender":"F",
        "locale":"서울 강남구",
    },
]

# %%
users.insert_many(many_user)

# %%
for user in users.find({}):
    print(user)
# Out:
# {'_id': ObjectId('5afc14aadabf947affd94358'), 'name': '김패캠', 'email': 'fckim@fastcampus.co.kr', 'phone': 1026547861, 'age': 28, 'gender': 'M', 'locale': '서울 강남구'}
# {'_id': ObjectId('5afc1b0cdabf947affd94359'), 'name': 'psy', 'email': 'jspark@fastcampus.co.kr', 'phone': 1012342850, 'age': 40, 'gender': 'M', 'locale': '서울 강남구'}
# {'_id': ObjectId('5afc1b0cdabf947affd9435a'), 'name': 'Gdragon', 'email': 'jypark@fastcampus.co.kr', 'phone': 1082651029, 'age': 29, 'gender': 'F', 'locale': '서울 강남구'}
# {'_id': ObjectId('5afc2c25dabf947affd9435c'), 'name': '김패캠', 'email': 'fckim@fastcampus.co.kr', 'phone': 1026547861, 'age': 28, 'gender': 'M', 'locale': '서울 강남구'}
# {'_id': ObjectId('5afc2c26dabf947affd9435d'), 'name': 'psy', 'email': 'jspark@fastcampus.co.kr', 'phone': 1012342850, 'age': 40, 'gender': 'M', 'locale': '서울 강남구'}
# ...

# %%
[user for user in users.find({})]
# Out:
# [{'_id': ObjectId('5afc14aadabf947affd94358'),
#   'name': '김패캠',
#   'email': 'fckim@fastcampus.co.kr',
#   'phone': 1026547861,
#   'age': 28,
#   'gender': 'M',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc1b0cdabf947affd94359'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc1b0cdabf947affd9435a'),
#   'name': 'Gdragon',
#   'email': 'jypark@fastcampus.co.kr',
#   'phone': 1082651029,
#   'age': 29,
#   'gender': 'F',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc2c25dabf947affd9435c'),
#   'name': '김패캠',
#   'email': 'fckim@fastcampus.co.kr',
#   'phone': 1026547861,
#   'age': 28,
#   'gender': 'M',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc2c26dabf947affd9435d'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'},
# ...

# %%
query = {
    "gender":"F"
}
[user for user in users.find(query)]
# Out:
# [{'_id': ObjectId('5afc1b0cdabf947affd9435a'),
#   'name': 'Gdragon',
#   'email': 'jypark@fastcampus.co.kr',
#   'phone': 1082651029,
#   'age': 29,
#   'gender': 'F',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc2c26dabf947affd9435e'),
#   'name': 'Gdragon',
#   'email': 'jypark@fastcampus.co.kr',
#   'phone': 1082651029,
#   'age': 29,
#   'gender': 'F',
#   'locale': '서울 강남구'}]

# %%
# AND Operator
query = {
    "gender":"M",
    "name":"psy",
}
[user for user in users.find(query)]
# Out:
# [{'_id': ObjectId('5afc1b0cdabf947affd94359'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc2c26dabf947affd9435d'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'}]

# %%
# WHERE name IN ("psy", "Gdragon")
query = {
    "name":{
        "$in": ["psy", "Gdragon"],
    },
}
[user for user in users.find(query)]
# Out:
# [{'_id': ObjectId('5afc1b0cdabf947affd94359'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc1b0cdabf947affd9435a'),
#   'name': 'Gdragon',
#   'email': 'jypark@fastcampus.co.kr',
#   'phone': 1082651029,
#   'age': 29,
#   'gender': 'F',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc2c26dabf947affd9435d'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc2c26dabf947affd9435e'),
#   'name': 'Gdragon',
#   'email': 'jypark@fastcampus.co.kr',
#   'phone': 1082651029,
#   'age': 29,
#   'gender': 'F',
#   'locale': '서울 강남구'}]

# %%
#gender 가 m이거나 age가 29
# age > 30
query = {
    "$or":[
        {"age":{"$lt":20}},
        {"age":{"$gte":30}},
    ],
}
[user for user in users.find(query)]
# Out:
# [{'_id': ObjectId('5afc1b0cdabf947affd94359'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc2c26dabf947affd9435d'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'}]

# %%
query = {
    "age":{"$gte":30}
}
[user for user in users.find(query)]
# Out:
# [{'_id': ObjectId('5afc1b0cdabf947affd94359'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'},
#  {'_id': ObjectId('5afc2c26dabf947affd9435d'),
#   'name': 'psy',
#   'email': 'jspark@fastcampus.co.kr',
#   'phone': 1012342850,
#   'age': 40,
#   'gender': 'M',
#   'locale': '서울 강남구'}]

# %%
# Select Specific value using key

query = {
    "age":{"$gte":30}
}
# 1
print("1.", [(user["name"], user["email"]) for user in users.find(query)])

# 2
print("2.", [user for user in users.find(query, {"name", "email"})])
# Out:
# 1. [('psy', 'jspark@fastcampus.co.kr'), ('psy', 'jspark@fastcampus.co.kr')]
# 2. [{'_id': ObjectId('5afc1b0cdabf947affd94359'), 'name': 'psy', 'email': 'jspark@fastcampus.co.kr'}, {'_id': ObjectId('5afc2c26dabf947affd9435d'), 'name': 'psy', 'email': 'jspark@fastcampus.co.kr'}]

# %%
z_uri = "https://api.zigbang.com/v3/items?detail=true&item_ids=[11488948,11535063,11464868,11315406,11392990,11566362,11323791,11598947,11525784,11503247,11600020,11369960,11520512,11437566,11564212,11463465,11567794,11603585,11565916,11596289,11530887,11509287,11598505,11601478,11316739,11592853,11271714,11431597,11321834,11556138,11068621,11349198,11553461,11542247,11575715,11316992,11581136,11556893,11555546,11369012,11479620,11413491,11586931,11369558,11604099,11561889,11388266,11600231,11580359,11395014,11361086,11473014,11139324,11509014,11590512,11327243,11575849,11587098,11534042,11347488]"

# %%
headers = {
    "Host":"api.zigbang.com",
    "Connection":"keep-alive",
    "Accept":"*/*",
    "Origin":"https://zigbang.com",
    "User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36",
    "Referer":"https://zigbang.com/search/map?lat=37.5499284&lng=126.914407&zoom=3&ad_id=47",
    "Accept-Encoding":"gzip, deflate, br",
    "Accept-Language":"ko,en-US;q=0.9,en;q=0.8,ko-KR;q=0.7,la;q=0.6",
}

# %%
response = requests.get(z_uri, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
zigbang = client.collections["zigbang"]
# zigbang = db["zigbang"]

# %%
zigbang.find_one()

# %%
response.text

# %%
lots_of_data = response.json()["items"]

# %%
zigbang.insert_many(lots_of_data)

# %%
[item for item in zigbang.find({})]
# Out:
# [{'_id': ObjectId('5afc2d1fdabf947affd9435f'),
#   'title': '서울시 마포구 서교동',
#   'header': False,
#   'header_height': 0,
#   'item': {'id': 11488948,
#    'images': [{'index': 0,
#      'count': 1,
#      'url': 'https://ic.zigbang.com/ic/users/902388/photos/uploads/63a4162c4a62365ba965f6aa55d746d00a3e43e4.2286609.JPG'},
#     {'index': 1,
#      'count': 2,
#      'url': 'https://ic.zigbang.com/ic/users/902388/photos/uploads/10e225f4bf1da95af375387204eab2085d029e82.2150645.JPG'},
#     {'index': 2,
#      'count': 3,
#      'url': 'https://ic.zigbang.com/ic/users/902388/photos/uploads/cb5d74a1ec04e7b10272fa0bff7373b49339c5b2.2288220.JPG'},
#     {'index': 3,
#      'count': 4,
#      'url': 'https://ic.zigbang.com/ic/users/902388/photos/uploads/bc084f40f74e56279d2e2193a57d1fbabe72ef70.2250738.JPG'},
#     {'index': 4,
#      'count': 5,
#      'url': 'https://ic.zigbang.com/ic/users/902388/photos/uploads/2467a46de1f672679d8a021260adb9bada86102f.2066195.JPG'},
#     {'index': 5,
# ...

# %%
zigbang.find({}).count()
# Out:
# 60

# %%
item_list = [item["item"]["deposit"] for item in zigbang.find({})]
item_list
# Out:
# [25000,
#  500,
#  4000,
#  19000,
#  21000,
#  7500,
#  1000,
#  14500,
#  6000,
#  17900,
#  1000,
#  1000,
#  3000,
#  3000,
#  20000,
#  500,
#  1000,
#  500,
#  1000,
#  1000,
#  2000,
#  1000,
#  1000,
#  4000,
#  24000,
#  1000,
#  500,
#  2000,
#  15000,
#  5000,
#  5000,
#  26500,
#  1000,
#  3000,
#  1000,
#  20000,
#  1500,
#  10000,
#  30000,
#  1000,
#  30000,
#  2000,
#  2000,
#  2000,
#  1000,
#  28000,
#  11000,
#  3000,
#  1000,
#  15000,
#  31000,
#  37700,
#  20000,
#  6500,
#  20000,
#  22000,
#  2000,
#  24000,
#  3000,
#  26500]

# %%
query = {
    "item.deposit":{"$lt":1000}
}
len([price for price in zigbang.find(query)])
# Out:
# 4

# %%
query = {
    "$or":[
        {"item.deposit":{"$lt":1000}},
        {"item.rent": {"$lt":40}}
        
    ]
}
len([price for price in zigbang.find(query)])
# Out:
# 33

# %%
cursor = zigbang.aggregate([
    {
        "$group":{
            "_id":"$item.address1",
            "count":{"$sum":1}, # $avg: $item.deposit
        }
    }
])
for item in cursor:
    print(item)
# Out:
# {'_id': '서울시 마포구 연남동', 'count': 2}
# {'_id': '서울시 마포구 창전동', 'count': 5}
# {'_id': '서울시 마포구 성산동', 'count': 4}
# {'_id': '서울시 마포구 동교동', 'count': 1}
# {'_id': '서울시 마포구 상수동', 'count': 2}
# {'_id': '서울시 마포구 서교동', 'count': 23}
# {'_id': '서울시 서대문구 창천동', 'count': 3}
# {'_id': '서울시 마포구 망원동', 'count': 8}
# {'_id': '서울시 마포구 합정동', 'count': 12}
